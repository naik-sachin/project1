# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from requests import get
from random import randint
from time import sleep
from bs4 import BeautifulSoup

# %%
"""My stab at pulling information from the actual IMDb website. title works but rating_find errors out to a blank list, or to just 4 ratings instead of all 930"""
pages = np.arange(1,1001,250)
title = []
rating = []
def webpageScraper():
    for page in pages:
        html = 'https://www.imdb.com/search/title/?release_date=1950-01-01,2020-12-31&groups=top_1000&sort=alpha,asc&count=250&start=' +str(page) +'&ref_=adv_nxt'
        response = get(html)
        html_soup = BeautifulSoup(response.text, 'html.parser')
        name_find = html_soup.find('div',class_ ='lister-list')
        rating_find = html_soup.find('p', class_ = 'text-muted')
        title_name = [h3.find('a').text for h3 in name_find.findAll('h3')]
        #rating = [p.find('span').text for p in rating_find.find('p')] #sets rating to an empty list or noneType have to look more into this... trying to pull the maturity rating for each movie 
        for name in title_name:
            title.append(name)
        sleep(randint(0,3))

# %%
"""using above function to pull everything. works but like commented above cant pull the ratings"""
webpageScraper()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-184-980905996c10> in <module>
#       1 """using above function to pull everything. works but like commented above cant pull the ratings"""
# ----> 2 webpageScraper()
#
# <ipython-input-183-9744707da149> in webpageScraper()
#      11         rating_find = html_soup.find('p', class_ = 'text-muted')
#      12         title_name = [h3.find('a').text for h3 in name_find.findAll('h3')]
# ---> 13         rating = [p.find('span').text for p in rating_find.find('p')] #sets rating to an empty list or noneType have to look more into this... trying to pull the maturity rating for each movie
#      14         for name in title_name:
#      15             title.append(name)
#
# TypeError: 'NoneType' object is not iterable

# %%
"""pulled all files from zip folder and put into dataframes"""

titles_df = pd.read_csv('Zipped_files/IMDb movies.csv')
names_df = pd.read_csv('Zipped_files/IMDb names.csv')
ratings_df = pd.read_csv('Zipped_files/IMDb ratings.csv')
title_principles_df = pd.read_csv('Zipped_files/IMDb title_principals.csv')

# %%
"""set each of the index's to make it easier for me to pull into one dataframe. commented out some to test that it was working
before finishing setting all index's"""
#ratings_df.set_index('imdb_title_id', inplace = True)
title_principles_df.set_index('imdb_name_id', inplace = True)
#titles_df.set_index('imdb_title_id', inplace = True)
#names_df.set_index('imdb_name_id', inplace = True)

# %%
"""making sure the heads are correct and set to right index"""
display(names_df.head())
title_principles_df.head()
# Out:
#                          name               birth_name  height  \
# imdb_name_id
# nm0000001        Fred Astaire  Frederic Austerlitz Jr.   177.0
# nm0000002       Lauren Bacall        Betty Joan Perske   174.0
# nm0000003     Brigitte Bardot          Brigitte Bardot   166.0
# nm0000004        John Belushi        John Adam Belushi   173.0
# nm0000005      Ingmar Bergman     Ernst Ingmar Bergman   179.0
#
#                                                             bio  \
# imdb_name_id
# nm0000001     Fred Astaire was born in Omaha, Nebraska, to J...
# nm0000002     Lauren Bacall was born Betty Joan Perske on Se...
# nm0000003     Brigitte Bardot was born on September 28, 1934...
# nm0000004     John Belushi was born in Chicago, Illinois, US...
# nm0000005     Ernst Ingmar Bergman was born July 14, 1918, t...
#
#                                                   birth_details  birth_year  \
# imdb_name_id
# nm0000001                  May 10, 1899 in Omaha, Nebraska, USA      1899.0
# ...

# %%
full_movie_db = titles_df.join(ratings_df, how = 'inner')
full_name_db = names_df.join(title_principles_df, how = 'inner')

# %%
full_movie_db.columns
full_name_db.columns
# Out:
# Index(['name', 'birth_name', 'height', 'bio', 'birth_details', 'birth_year',
#        'date_of_birth', 'place_of_birth', 'death_details', 'death_year',
#        'date_of_death', 'place_of_death', 'reason_of_death', 'spouses',
#        'divorces', 'spouses_with_children', 'children', 'primary_profession',
#        'known_for_titles', 'ordering', 'category', 'job', 'characters'],
#       dtype='object')

# %%
#full_name_db.set_index('known_for_titles', inplace = True)
#full_movie_db.join(full_name_db, how = 'outer')
full_movie_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81273 entries, tt0000574 to tt9914286
# Data columns (total 69 columns):
# title                        81273 non-null object
# original_title               81273 non-null object
# year                         81273 non-null int64
# date_published               81273 non-null object
# genre                        81273 non-null object
# duration                     81273 non-null int64
# country                      81234 non-null object
# language                     80518 non-null object
# director                     81200 non-null object
# writer                       79780 non-null object
# production_company           76948 non-null object
# actors                       81207 non-null object
# description                  78843 non-null object
# avg_vote                     81273 non-null float64
# votes                        81273 non-null int64
# budget                       22804 non-null object
# ...

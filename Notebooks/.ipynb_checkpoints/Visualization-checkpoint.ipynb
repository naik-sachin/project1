# %% [markdown]
# # Exploratory Data Analysis for Microsoft

# %% [markdown]
# ###  About: The notebook contains the analysis of IMDBs Top 1000 movies . The goal of this analysis is to offer meaningful insights to a new movie production company by answering the following questions.

# %% [markdown]
# 1. What kind of Budget would be needed.
# 2. What genre of Movies will yield the best return.
# 3. What runtime is ideal for each of the genres.
# 4. Which Director would be ideal.

# %%
"""Getting all relevent imports into the file"""
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
"""Our Data frame that contains information From IMDBs website and learn-co project repo"""
fulldf=pd.read_csv('fulldf.csv')

# %%
fulldf.head() # Display the Data to make sure its what is desired.

# %% [markdown]
# ### 1. What kind of budget is needed?

# %%
"""Funtion to plot bargraphs using the (Dataframe, xvalues,yvalues,string title"""
# We will plot bar graphs more than twice so makes sense to have a funtion do this
def bargraph (Dataframe,xColumn,yColumn,str):
    plt.figure(figsize=(15,10))
    sns.barplot(y=yColumn,x=xColumn)
    plt.title(str)

# %%
"""Funtion to graph boxplot using the (Data,string title)"""
# We will make a boxplot graphs than twice so makes sense to have a funtion do this
def boxplot (Data,str):
    plt.figure(figsize=(10,5))
    sns.boxplot(Data)
    plt.title(str,weight='bold').set_fontsize('18')
    plt.show()
    return Data.describe()

# %%
"""Look at the Budget of the Top 20 Grossing movies  """
# Create new df with sorted gross income values and limit to top 20
group_df = fulldf.sort_values('Gross Income in millions (USD)',ascending=False).reset_index().head(20)
# Pass this Data through the bargraph funtion so we can plot a Bar graphh
bargraph(group_df,group_df['Gross Income in millions (USD)'],group_df['Title'],"Top 20 Grossing Movies")

# %%
"""Look at the Proft Percent Return of the Top 20 Grossing movies  """
group_df = fulldf.sort_values('Profit percent',ascending=False).reset_index().head(20)
bargraph(group_df,group_df['Profit percent'],group_df['Title'],"Top 20 Most Profitable Movies")

# %% [markdown]
# ### We can see that none of the top Grossing movies are among the most profitable ,So does a big budget movie necessarily give a better return in terms of an investment? Down below we examine IMDb Top 1000 to answer this question.

# %%
"""Create a new data frame so we can populate it without outliers """
#New dataframe with only the Money figures to answer the buget question
testdf = fulldf[['Profit percent','Gross Income in millions (USD)','Budget in millions (USD)']]

# %%
#testdf.info() # Check to make sure the dataframe is as desired.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 3 columns):
# Profit percent                    474 non-null float64
# Gross Income in millions (USD)    474 non-null float64
# Budget in millions (USD)          474 non-null float64
# dtypes: float64(3)
# memory usage: 11.2 KB

# %%
"""Keep data values within  3 Standard deviation of each column to remove outliers, """
# Calculate the z scores of all entries , only keep entries that are less than 3 std in sach cell
testdf=testdf[(np.abs(stats.zscore(testdf)) < 3).all(axis=1)]

# %%
#testdf.info() # Check to make sure the dataframe .

# %% [markdown]
# ### For the Top1000 movies As Budget of a movie increases Gross income increases

# %%
"""Visualtize to see what happens to Budget as Gross Income increases"""
plt.figure(figsize=(15,10))
sns.regplot(x=testdf['Budget in millions (USD)'], y=testdf['Gross Income in millions (USD)'],data=testdf)
plt.title('Gross Income vs Budget in millions (USD) for Top 1000 IMDb movies',weight='bold').set_fontsize('18')

# %% [markdown]
# ### But as Budget increases percent profit actually decreases.

# %%
"""Visualtize to see what happens to Percent Profit as Gross Income increases"""
plt.figure(figsize=(15,10))
sns.regplot(x=testdf['Budget in millions (USD)'], y=testdf['Profit percent'],data=testdf,color='red')
plt.title('Profit percent vs Budget in millions (USD) for Top 1000 IMDb movies',weight='bold').set_fontsize('18')

# %% [markdown]
# ###  Although investing a larger amount could lead to a large return it also involves a lot more risk and a relatively smaller percent profit ! We would recommend a smaller budget to start, as examined below.

# %%
"""Look at the overall central tendency of Budget in millions(USD)"""
boxplot(fulldf['Budget in millions (USD)'],'Budgets of Top 1000 IMDb movies')
# Out:
# count    474.000000
# mean      46.484499
# std       58.688403
# min        0.027000
# 25%       10.000000
# 50%       23.300000
# 75%       60.000000
# max      425.000000
# Name: Budget in millions (USD), dtype: float64

# %% [markdown]
# ### Since the Movie Budget has a lot of outliers it would be better to use the median of about 24 million as a measure of its central tendecy.

# %%
"""Look at the overall central tendency of Percent Profit """

boxplot(fulldf['Profit percent'],'Profit Percent of Top 1000 IMDb movies')
# Out:
# count      474.000000
# mean       412.312573
# std       1296.203181
# min       -100.000000
# 25%         16.915000
# 50%        110.437963
# 75%        340.576923
# max      14361.538462
# Name: Profit percent, dtype: float64

# %% [markdown]
# ### Since the Percent Profit for movies has a lot of outliers it would be better to use the median of 110% as a measure of its central tendecy

# %% [markdown]
# ### INSIGHT 1: Based on our analysis it seems a budget of about 24 million would be a good starting point , With a movie of this budget we can expect a return of about 110%.

# %%
#group_df = fulldf.sort_values('Gross Income in millions (USD)',ascending=False).reset_index().head(20) # Creat new df with sorted gross income values and limit to top 20
#group_df['Budget in millions (USD)'].describe()

# %% [markdown]
# plt.figure(figsize=(10,5))
# sns.boxplot(group_df['Budget in millions (USD)'])
# plt.title('Budget of the Top 20 Grossing Movies ')
# plt.show()
# group_df['Budget in millions (USD)'].describe()
# #bargraph(group_df,group_df['Gross Income in millions (USD)'],group_df['Title'],"Top 20 Grossing Movies Budget")

# %% [markdown]
# plt.figure(figsize=(10,5))
# sns.boxplot(group_df['Profit percent'])
# plt.title('Profit Perent of the Top 20 Grossing Movies ')
# plt.show()
# group_df['Profit percent'].describe()

# %% [markdown]
# # Top 20 Grossing movies had a median buget of about 180 million with an median return of 183%

# %% [markdown]
# # Budget Keytakeaway: Based on our Budget analysis our Budget varies between 24 million and 180 million depending on how much risk Microsoft wants to take.

# %% [markdown]
# # What genres generated most Gross Income

# %%
#Genre_group_df = fulldf.groupby('Movie Genre')['Movie Genre','Gross Income'].mean() # new df with groped data based on genre, along with related gross income means

# %%
#Genre_group_df = Genre_group_df.sort_values('Gross Income',ascending=False).reset_index().head(20)# sort the df based on Gross income values, limi to top 20

# %%
#bargraph(Genre_group_df,Genre_group_df['Gross Income'],Genre_group_df['Movie Genre'],"Top 20 Grossing Movie Genres using average Gross Income")

# %% [markdown]
# # What Genres yielded the best returns ?

# %%
Genre_group_df = fulldf.groupby('Movie Genre')['Movie Genre','Profit percent'].mean()

# %%
Genre_group_df = Genre_group_df.sort_values('Profit percent',ascending=False).reset_index().head(20)

# %%
bargraph(Genre_group_df,Genre_group_df['Profit percent'],Genre_group_df['Movie Genre'],"Genres of the Top 20 most proftiable Movies")

# %%
fulldf['Movie Genre'] =fulldf['Movie Genre'].str.strip('[]''').str.split(',')

# %%
single_genre_df = fulldf.explode('Movie Genre')

# %%
single_genre_df = single_genre_df.groupby('Movie Genre').mean()

# %%
single_genre_df=single_genre_df.sort_values('Profit percent',ascending=False).reset_index()

single_genre_df.head(35)
# Out:
#       Movie Genre         Year  Gross Income in millions (USD)  Movie Runtime  \
# 0        'Horror'  1985.000000                       82.715000     104.100000
# 1      ' Western'  1985.571429                      108.632857     128.428571
# 2        ' Sport'  2002.785714                       73.705000     126.214286
# 3       ' Family'  1984.107143                      138.162857     114.750000
# 4        ' Music'  2002.833333                       57.747500     117.583333
# 5        'Comedy'  1995.160714                       48.719464     106.321429
# 6      ' Fantasy'  1993.611111                      146.773611     123.361111
# 7      ' Musical'  1970.333333                       30.546667     130.166667
# 8    ' Film-Noir'  1951.000000                        7.630000     101.000000
# 9     'Animation'  1998.425000                      202.076250      96.000000
# 10    ' Thriller'  1996.188406                       81.661449     119.579710
# 11     ' Romance'  1998.319149                       72.219362     122.553191
# 12        'Drama'  1995.949580                       65.647311     130.487395
# 13     ' History'  1992.518519                       73.917037     154.814815
# 14         ' War'  1987.111111                       67.014444     142.444444
# 15     ' Mystery'  2001.820513                       76.060256     127.615385
# 16        'Crime'  1996.627907                       60.828605     135.465116
# 17    'Adventure'  1989.000000                      107.053913     144.891304
# 18       ' Crime'  1999.230769                       66.989744     120.641026
# 19    'Biography'  2001.413793                       69.925000     133.689655
# 20       ' Drama'  1999.307692                       74.315692     133.379487
# 21   ' Adventure'  2002.646341                      230.184390     118.097561
# 22       'Action'  2002.031250                      171.364687     127.197917
# 23      ' Comedy'  2002.255319                      157.322766     104.765957
# 24      ' Sci-Fi'  1997.775862                      145.316207     122.517241
# 25      'Mystery'  2000.750000                       56.267500     120.000000
# 26      ' Action'  2011.125000                      227.008750     102.750000
# 27      ' Horror'  1984.750000                       15.870000     116.500000
# 28   ' Biography'  1989.857143                       27.710000     160.857143
# 29       'Family'  1971.000000                        4.000000     100.000000
# 30      'Western'  1968.000000                        5.320000     165.000000
#
#     IMDb Rating          Votes  Budget in millions (USD)  Profit percent
# 0      7.930000  388300.100000                 12.922500     2587.466617
# 1      7.957143  357569.857143                 25.390000     1102.252550
# 2      7.892857  343841.428571                 25.642857     1002.719970
# 3      7.828571  270872.892857                 63.303393      933.623084
# 4      7.891667  256313.083333                 17.159167      912.369009
# 5      7.823214  274234.053571                 11.265661      725.959190
# 6      7.897222  486434.333333                 74.170694      618.590099
# 7      7.916667  107528.500000                  7.433333      615.450928
# 8      8.000000  120281.000000                  1.200000      535.833333
# 9      7.892500  398517.800000                104.759200      528.826364
# 10     7.895652  451512.304348                 35.183450      503.303070
# 11     7.885106  344237.000000                 24.072957      465.355834
# 12     7.942857  380028.310924                 24.791198      446.377338
# 13     7.888889  255979.592593                 39.770370      319.223752
# 14     8.022222  385642.000000                 35.685500      307.207707
# 15     7.946154  487901.794872                 46.951282      277.644512
# 16     8.039535  558600.069767                 32.993095      271.218994
# 17     8.000000  443277.869565                 54.251674      258.832539
# 18     7.856410  398798.512821                 32.806410      224.268367
# 19     7.891379  312145.982759                 30.844828      219.804318
# 20     7.931282  396650.923077                 37.127708      214.490832
# 21     7.923171  568928.817073                116.967073      200.692040
# 22     7.900000  568276.927083                 86.257812      184.975181
# 23     7.876596  443961.042553                 77.730851      178.756285
# 24     7.993103  610975.000000                 75.018966      153.617087
# 25     8.050000  732211.500000                 35.250000      130.276561
# 26     7.850000  352331.250000                116.500000       92.561913
# 27     8.025000  376231.500000                  7.675000       67.906767
# 28     7.928571  179335.428571                 20.614286       50.777385
# 29     7.800000  172756.000000                  3.000000       33.333333
# 30     8.500000  292618.000000                  5.000000        6.400000

# %%
bargraph(single_genre_df,single_genre_df['Profit percent'],single_genre_df['Movie Genre'],"Profit percent return on movie genres based on IMDb Top1000")

# %% [markdown]
# # What Genres were the most popular among the Top 1000 based on IMDb ratings ?

# %% [markdown]
# single_genre_df=single_genre_df.sort_values('IMDb Rating',ascending=False).reset_index()

# %% [markdown]
# bargraph(single_genre_df,single_genre_df['IMDb Rating'],single_genre_df['Movie Genre'],"Movie popularity of each genre based on IMDb rating ")

# %% [markdown]
# # Keytakeaways: Movies that made the most profit  have a combination of genres as opposed to a single genre. Among that Seems action,adventure,animation were top grossing whereas Horror ,Western,Sport made the most profit.

# %%
single_genre_df=single_genre_df.sort_values('IM',ascending=False).reset_index()

# %% [markdown]
# group_df = fulldf.groupby('Movie Genre')['Movie Genre','IMDb Rating'].mean()
# group_df.head()

# %% [markdown]
# group_df = group_df.sort_values('IMDb Rating',ascending=False).reset_index().head(20)

# %% [markdown]
# bargraph(group_df,group_df['IMDb Rating'],group_df['Movie Genre'],"Top20 most popular Genres among audiiences using average IMDb rating")

# %% [markdown]
# # Since each second of movie production costs money what runtime would be ideal to maximize returns for each genre

# %%
fulldf.head()
# Out:
#                    Title Movie Rating  Year               Director  \
# 0       12 Years a Slave            R  2013          Steve McQueen
# 1              127 Hours            R  2010            Danny Boyle
# 2  2001: A Space Odyssey            G  1968        Stanley Kubrick
# 3               21 Grams            R  2003  Alejandro G. Iñárritu
# 4              25th Hour            R  2002              Spike Lee
#
#    Gross Income in millions (USD)                            Movie Genre  \
# 0                           56.67  ['Biography',  ' Drama',  ' History']
# 1                           18.34               ['Biography',  ' Drama']
# 2                           56.95              ['Adventure',  ' Sci-Fi']
# 3                           16.29     ['Crime',  ' Drama',  ' Thriller']
# 4                           13.06                              ['Drama']
#
#    Movie Runtime  IMDb Rating     Votes  Budget in millions (USD)  \
# 0            134          8.1  620348.0                      20.0
# 1             94          7.6  340655.0                      18.0
# 2            149          8.3  583340.0                      10.5
# 3            124          7.7  220522.0                      20.0
# 4            135          7.6  167314.0                       4.5
#
#    Profit percent
# 0      183.350000
# 1        1.888889
# 2      442.380952
# 3      -18.550000
# 4      190.222222

# %%
single_genre_df=single_genre_df.sort_values('Movie Runtime',ascending=False).reset_index()

# %%
bargraph(single_genre_df,single_genre_df['Movie Runtime'],single_genre_df['Movie Genre'],"Average Runtime of movies based on Genre")
#plt.text('2', ha='center', va='bottom')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-ad8e09b1e637> in <module>
#       1 bargraph(single_genre_df,single_genre_df['Movie Runtime'],single_genre_df['Movie Genre'],"Average Runtime of movies based on Genre")
# ----> 2 plt.text('2', ha='center', va='bottom')
#
# TypeError: text() missing 2 required positional arguments: 'y' and 's'

# %% [markdown]
# Dcounts = fulldf.groupby('Movie Genre').count()
# Dcounts= Dcounts.sort_values('Title',ascending=False).reset_index().head(20)

# %%
Dcounts.rename(columns = {'Title':'Title count'}, inplace = True)

# %%
plt6=sns.barplot(y=Dcounts['Movie Genre'],x=Dcounts['Title count'])
#Dcounts.sort_values('Director',ascending=False)

# %%
sns.boxplot(fulldf['Movie Runtime'])

# %%
fulldf['Movie Runtime'].describe()
# Out:
# count    474.000000
# mean     125.660338
# std       28.658679
# min       78.000000
# 25%      105.000000
# 50%      121.500000
# 75%      139.000000
# max      242.000000
# Name: Movie Runtime, dtype: float64

# %%
upoutlier =125.66 + 3*28.66 # 211.64
lowoutlier = 125.66 - 3*28.66 # 39.68
print ("IMDb Top 1000 movies have a Max runtime of {} minutes, Anything higher that that is unusual. ".format(upoutlier))
# Out:
# IMDb Top 1000 movies have a Max runtime of 211.64 minutes, Anything higher that that is unusual.

# %% [markdown]
# # In the Top1000 Movies considering each second of movie production costs money , a max runtime of approx 212 min is ideal. This is further validated by the runtime of top20 grossing and top20 most profitable as shown below. (Gone with the wind is an outlier)

# %%
sns.distplot(fulldf['Movie Runtime'])

# %%
group_df = fulldf.sort_values('Gross_Income',ascending=False).reset_index().head(20) # Creat new df with sorted gross income values and limit to top 20

# %%
plt.figure(figsize=(15,10))
plt.title("Top 20 Grossing Movies Runtime")
plt8=sns.barplot(y=group_df.Title,x=group_df['Movie Runtime'])

# %%
group_df = fulldf.sort_values('Profit_percent',ascending=False).reset_index().head(20)

# %%
plt.figure(figsize=(15,10))
plt.title("Top 20 Most Profitable Movies Runtime")
plt9=sns.barplot(y=group_df.Title,x=group_df['Movie Runtime'])
#plt9.set_xticklabels(plt9.get_xticklabels(), rotation=90)

# %% [markdown]
# # Top 20 Grossing movies had an average budget of 174 million

# %%
group_df = fulldf.sort_values('Profit_percent',ascending=False).reset_index().head(20)
plt.figure(figsize=(15,10))
plt.title("Top 20 Most Profitable Movies Budget")
plt12=sns.barplot(y=group_df.Title,x=group_df.Budget)

# %%
group_df['Budget'].describe()
# Out:
# count    20.00000
# mean      3.69650
# std       3.59768
# min       0.02700
# 25%       1.00000
# 50%       2.70000
# 75%       5.12500
# max      12.00000
# Name: Budget, dtype: float64

# %% [markdown]
# # Top 20 most profitable movies had an average budget of approx 4 million

# %% [markdown]
# # So perhaps microsoft wants to invest less and do it more often so theres less risk per investment or take a bigger risk and do a full blown production ...upto companies goals/agressiveness etc?

# %%
director_df=fulldf.groupby('Director').count()

# %%
director_df=director_df.sort_values('Title',ascending=False).reset_index().head(20)

# %%
director_df.head()
# Out:
#    index           Director  Title  Movie Rating  Year  Gross_Income  \
# 0      0   Steven Spielberg     10            10    10            10
# 1      1  Christopher Nolan      8             8     8             8
# 2      2    Martin Scorsese      8             8     8             8
# 3      3      David Fincher      8             8     8             8
# 4      4     Clint Eastwood      7             7     7             7
#
#    Movie_Genre  Movie Runtime  IMDb Rating  Votes  Budget  Profit_percent
# 0           10             10           10     10      10              10
# 1            8              8            8      8       8               8
# 2            8              8            8      8       8               8
# 3            8              8            8      8       8               8
# 4            7              7            7      7       7               7

# %%
plt.title(" Directors that have directed most # of top 1000 movies")
plt13=sns.barplot(y=director_df.Director,x=director_df.Title)

# %%
# Out:
#               Title Movie Rating  Year       Director  Gross Income  \
# 0  12 Years a Slave            R  2013  Steve McQueen         56.67
# 0  12 Years a Slave            R  2013  Steve McQueen         56.67
# 0  12 Years a Slave            R  2013  Steve McQueen         56.67
# 1         127 Hours            R  2010    Danny Boyle         18.34
# 1         127 Hours            R  2010    Danny Boyle         18.34
#
#     Movie Genre  Movie Runtime  IMDb Rating     Votes  Budget  Profit percent
# 0  ['Biography'            134          8.1  620348.0    20.0      183.350000
# 0      ' Drama'            134          8.1  620348.0    20.0      183.350000
# 0   ' History']            134          8.1  620348.0    20.0      183.350000
# 1  ['Biography'             94          7.6  340655.0    18.0        1.888889
# 1     ' Drama']             94          7.6  340655.0    18.0        1.888889
